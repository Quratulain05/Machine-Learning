# %%
print("hello")
# Out:
# hello

# %%
# !pip install numpy

# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.5 MB 1.3 MB/s eta 0:00:09
#    - -------------------------------------- 0.5/11.5 MB 1.3 MB/s eta 0:00:09
#    -- ------------------------------------- 0.8/11.5 MB 1.0 MB/s eta 0:00:11
#    -- ------------------------------------- 0.8/11.5 MB 1.0 MB/s eta 0:00:11
#    --- ------------------------------------ 1.0/11.5 MB 794.6 kB/s eta 0:00:14
#    --- ------------------------------------ 1.0/11.5 MB 794.6 kB/s eta 0:00:14
#    ---- ----------------------------------- 1.3/11.5 MB 762.2 kB/s eta 0:00:14
#    ----- ---------------------------------- 1.6/11.5 MB 765.9 kB/s eta 0:00:13
#    ----- ---------------------------------- 1.6/11.5 MB 765.9 kB/s eta 0:00:13
#    ------ --------------------------------- 1.8/11.5 MB 748.2 kB/s eta 0:00:13
# ...

# %%
import numpy as np

# %%
import pandas as pd
