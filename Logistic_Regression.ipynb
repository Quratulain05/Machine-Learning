# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age,df.bought_insurance,marker='+',color='purple')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,train_size=0.8)

# %%
X_test
# Out:
#     age
# 26   23
# 3    52
# 15   55
# 8    62
# 2    47
# 4    46

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     age
# 26   23
# 3    52
# 15   55
# 8    62
# 2    47
# 4    46

# %%
y_predicted = model.predict(X_test)

# %%
model.predict_proba(X_test)
# Out:
# array([[0.89518953, 0.10481047],
#        [0.11384312, 0.88615688],
#        [0.07682843, 0.92317157],
#        [0.0293322 , 0.9706678 ],
#        [0.20941424, 0.79058576],
#        [0.23438089, 0.76561911]])

# %%
model.score(X_test,y_test)
# Out:
# 0.8333333333333334

# %%
y_predicted
# Out:
# array([0, 1, 1, 1, 1, 1])

# %%
X_test
# Out:
#     age
# 26   23
# 3    52
# 15   55
# 8    62
# 2    47
# 4    46

# %%
model.coef_
# Out:
# array([[0.14472257]])

# %%
model.intercept_
# Out:
# array([-5.47350088])

# %%
import math
def sigmoid(x):
  return 1 / (1 + math.exp(-x))

# %%
def prediction_function(age):
    z = 0.042 * age - 5.4 # 0.04150133 ~ 0.042 and -1.52726963 ~ -1.53
    y = sigmoid(z)
    return y

# %%
age = 35
prediction_function(age)
# Out:
# 0.019265232631591675
